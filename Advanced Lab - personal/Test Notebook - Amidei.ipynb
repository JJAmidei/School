# %% [markdown]
# # Test Notebook - James Amidei
# ----------------------------------------------------
#
# This is a test jupyter notebook for Advanced Lab 1.
#
# In a markdown cell, we can shockingly format our text using markdown.
#
# We can bold things by adding `**` on either side of our text like below.
#
# `**Here is some bolded text**` = **Here is some bolded text**
#
# Similarly, we can italicize text by adding a single `*` on either side of text like below.
#
# `*Here is some text that's italicized*` = *Il corsivo non significa che il testo è tradotto in italiano.*
#
# We can add equations by using `$` on either side of some math. For example
#
# $$ E = \gamma m_{0} c^2 $$
#
# We've already seen a couple of times above, we can seperate commands by adding ` `` ` around them. If add three on either side, we can use that same character to seperate chunks of code. For example:
#
# ```
# def factorial(n):
#     if n == 0:
#         return 1
#     else:
#         return n * factorial(n - 1)
# ```
#
# Speaking of code, let's run that code in a code cell below.

# %%
def factorial(n): # Function that allows us to find the factorial of a number. 
    if n == 0:
        return 1
    else:
        return n * factorial(n - 1)
    
factorial(500)
# Out:
# ...

# %% [markdown]
# As a final note, here's a plot.

# %%
import matplotlib.pyplot as plt
import numpy as np

physics = [0.5, 1, 1.5, 2, 2.5]
coding = [10, 20, 50, 100, 200]

fig, ax = plt.subplots()

plt.scatter(physics, coding, label='Data Points', color='blue')

params = np.polyfit(physics, np.log(coding), 1)
a, b = params
y_fit = np.exp(a * np.array(physics) + b)

plt.plot(physics, y_fit, label=f'Exponential Fit (y = e^{a:.2f}x)', color='red')

plt.xlabel('Level of physics (year)')
plt.ylabel('Amount of coding (minutes per day)')
plt.title('Level of physics vs. Amount of coding I have to do')
plt.legend()

plt.grid(True)
plt.show()
