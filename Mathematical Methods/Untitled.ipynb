# %%
import numpy as np
import matplotlib.pyplot as plt

x = np.linspace(-10, 10, 100)
y = np.linspace(-10, 10, 100)

X, Y = np.meshgrid(x, y)

T_values = X * Y - X

isothermal_T_values = [-2, -1, 0, 1, 2]

colors = ['blue', 'green', 'red', 'purple', 'orange']

for T, color in zip(isothermal_T_values, colors):
    plt.contour(X, Y, T_values, levels=[T], colors=[color])
        
plt.xlabel('x')
plt.ylabel('y')
plt.title('Isothermal Curves for T = xy - x')
plt.grid(True)
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

x = np.linspace(-10, 10, 100)
y = np.linspace(-10, 10, 100)

X, Y = np.meshgrid(x, y)

T_values = X * Y - X
isothermal_T_values = [-2, -1, 0, 1, 2]
colors = ['blue', 'green', 'red', 'purple', 'orange']

for T, color in zip(isothermal_T_values, colors):
    plt.contour(X, Y, T_values, levels=[T], colors=[color])
    
x_point = 1
y_point = 1
grad_x = y_point - 1
grad_y = x_point
plt.quiver(x_point, y_point, -grad_x, -grad_y, angles='xy', scale_units='xy', 
           scale=1, color='magenta', label='Gradient at (1, 1)')      

plt.xlabel('x')
plt.ylabel('y')
plt.title('Isothermal Curves for T = xy - x')
plt.grid(True)
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

x = np.linspace(-10, 10, 20)
y = np.linspace(-10, 10, 20)

X, Y = np.meshgrid(x, y)

dT_dx = (1-Y) * 0.1  # I changed the scale of each vector because it was illegible otherwise. 
dT_dy = -X * 0.1       

plt.figure(figsize=(8, 8))
plt.quiver(X, Y, dT_dx, dT_dy, color='blue')
plt.xlabel('x')
plt.ylabel('y')
plt.title('Gradient Field of T = xy - x')
plt.grid()
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

x = np.arange(-10, 11)  # Define the range of x
center = 0  n

# Create a list of impulse values (use 1 for the impulse point, 0 elsewhere)
delta_impulses = np.where(x == center, 1, 0)

# Plot
plt.stem(x, delta_impulses, linefmt='-b', markerfmt='bo', basefmt=' ', label='Delta(x)')
plt.title('Dirac Delta Function (Discrete Impulses)')
plt.xlabel('x')
plt.ylabel('Delta(x)')
plt.legend()
plt.grid(True)
plt.show()

# %%
from sympy import DiracDelta, diff, pi
from sympy.abc import x, y

DiracDelta(2)
# Out:
# 0

# %%
import numpy as np
import matplotlib.pyplot as plt
  
t = np.arange(0, 1, 0.01)  
omega_0 = 2  

f=np.sin(2*np.pi*omega_0*t)

fourier_transform = np.fft.fft(f)
frequencies = np.fft.fftfreq(len(t), 0.01)

plt.figure(figsize=(12, 4))
plt.subplot(121)
plt.plot(t, sine_wave)
plt.title('Sine Wave')
plt.xlabel('Time (s)')
plt.ylabel('Amplitude')
plt.grid(True)

plt.subplot(122)
plt.plot(frequencies, np.abs(fourier_transform))
plt.title('Fourier Transform')
plt.xlabel('Frequency (Hz)')
plt.ylabel('Magnitude')
plt.grid(True)
plt.tight_layout()
plt.show()
