# %%
import numpy as np
import matplotlib.pyplot as plt 

x = np.linspace(0, 10)
y = np.linspace(0, 10)
I = np.array([1.0, 0., 0.]) # Amps
B = np.array([0., 0., 1.0]) # Tesla
A = 1.0 # meters squared
m = A*I # A*m^2


plt.figure()
plt.plot(x, y)
plt.show()
